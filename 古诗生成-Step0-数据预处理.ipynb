# %%
# coding:utf-8
import sys
import os
import json
import re
import numpy as np

# %%
def _parseRawData(author=None, constrain=None, src='./chinese-poetry/json/', category="poet.tang|poet.song"):
    """
    code from https://github.com/justdark/pytorch-poetry-gen/blob/master/dataHandler.py
    处理json文件，返回诗歌内容
    @param: author： 作者名字
    @param: constrain: 长度限制
    @param: src: json 文件存放路径
    @param: category: 类别，有poet.song 和 poet.tang

    返回 data：list
        ['床前明月光，疑是地上霜，举头望明月，低头思故乡。',
         '一去二三里，烟村四五家，亭台六七座，八九十支花。',
        .........
        ]
    """

    def sentenceParse(para):
        # para 形如 "-181-村橋路不端，數里就迴湍。積壤連涇脉，高林上笋竿。早嘗甘蔗淡，
        # 生摘琵琶酸。（「琵琶」，嚴壽澄校《張祜詩集》云：疑「枇杷」之誤。）
        # 好是去塵俗，煙花長一欄。"
        result, number = re.subn(u"（.*）", "", para)
        result, number = re.subn(u"{.*}", "", result)
        result, number = re.subn(u"《.*》", "", result)
        result, number = re.subn(u"《.*》", "", result)
        result, number = re.subn(u"[\]\[]", "", result)
        r = ""
        for s in result:
            if s not in set('0123456789-'):
                r += s
        r, number = re.subn(u"。。", u"。", r)
        return r

    def handleJson(file):
        # print file
        rst = []
        print("Processing " +file)
        data = json.loads(open(file, encoding='utf-8').read())
        for poetry in data:
            pdata = ""
            if (author is not None and poetry.get("author") != author):
                continue
            p = poetry.get("paragraphs")
            flag = False
            for s in p:
                sp = re.split(u"[，！。]", s)
                for tr in sp:
                    if constrain is not None and len(tr) != constrain and len(tr) != 0:
                        flag = True
                        break
                    if flag:
                        break
            if flag:
                continue
            for sentence in poetry.get("paragraphs"):
                pdata += sentence
            pdata = sentenceParse(pdata)
            if pdata != "":
                rst.append(pdata)
        return rst

    data = []
    for filename in os.listdir(src):
        if filename.startswith(category):
            data.extend(handleJson(src + filename))
    return data

# %%
def pad_sequences(sequences,
                  maxlen=None,
                  dtype='int32',
                  padding='pre',
                  truncating='pre',
                  value=0.):
    """
    code from keras
    Pads each sequence to the same length (length of the longest sequence).
    If maxlen is provided, any sequence longer
    than maxlen is truncated to maxlen.
    Truncation happens off either the beginning (default) or
    the end of the sequence.
    Supports post-padding and pre-padding (default).
    Arguments:
        sequences: list of lists where each element is a sequence
        maxlen: int, maximum length
        dtype: type to cast the resulting sequence.
        padding: 'pre' or 'post', pad either before or after each sequence.
        truncating: 'pre' or 'post', remove values from sequences larger than
            maxlen either in the beginning or in the end of the sequence
        value: float, value to pad the sequences to the desired value.
    Returns:
        x: numpy array with dimensions (number_of_sequences, maxlen)
    Raises:
        ValueError: in case of invalid values for `truncating` or `padding`,
            or in case of invalid shape for a `sequences` entry.
    """
    if not hasattr(sequences, '__len__'):
        raise ValueError('`sequences` must be iterable.')
    lengths = []
    for x in sequences:
        if not hasattr(x, '__len__'):
            raise ValueError('`sequences` must be a list of iterables. '
                             'Found non-iterable: ' + str(x))
        lengths.append(len(x))

    num_samples = len(sequences)
    if maxlen is None:
        maxlen = np.max(lengths)

    # take the sample shape from the first non empty sequence
    # checking for consistency in the main loop below.
    sample_shape = tuple()
    for s in sequences:
        if len(s) > 0:  # pylint: disable=g-explicit-length-test
            sample_shape = np.asarray(s).shape[1:]
            break

    x = (np.ones((num_samples, maxlen) + sample_shape) * value).astype(dtype)
    for idx, s in enumerate(sequences):
        if not len(s):  # pylint: disable=g-explicit-length-test
            continue  # empty list/array was found
        if truncating == 'pre':
            trunc = s[-maxlen:]  # pylint: disable=invalid-unary-operand-type
        elif truncating == 'post':
            trunc = s[:maxlen]
        else:
            raise ValueError('Truncating type "%s" not understood' % truncating)

        # check `trunc` has expected shape
        trunc = np.asarray(trunc, dtype=dtype)
        if trunc.shape[1:] != sample_shape:
            raise ValueError(
                'Shape of sample %s of sequence at position %s is different from '
                'expected shape %s'
                % (trunc.shape[1:], idx, sample_shape))

        if padding == 'post':
            x[idx, :len(trunc)] = trunc
        elif padding == 'pre':
            x[idx, -len(trunc):] = trunc
        else:
            raise ValueError('Padding type "%s" not understood' % padding)
    return x

# %%
# coding:utf-8
# 如果没有处理好的二进制文件，则处理原始的json文件
data = _parseRawData(author=None, constrain=None, 
                     src = "C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/",  
                     category="poet.")
words = {_word for _sentence in data for _word in _sentence}
word2ix = {_word: _ix for _ix, _word in enumerate(words)}
word2ix['<EOP>'] = len(word2ix)  # 终止标识符
word2ix['<START>'] = len(word2ix)  # 起始标识符
word2ix['</s>'] = len(word2ix)  # 空格
ix2word = {_ix: _word for _word, _ix in list(word2ix.items())}

# 为每首诗歌加上起始符和终止符
for i in range(len(data)):
    data[i] = ["<START>"] + list(data[i]) + ["<EOP>"]

# 将每首诗歌保存的内容由‘字’变成‘数’
# 形如[春,江,花,月,夜]变成[1,2,3,4,5]
new_data = [[word2ix[_word] for _word in _sentence] 
            for _sentence in data]

# 诗歌长度不够opt.maxlen的在前面补空格，超过的，删除末尾的
pad_data = pad_sequences(new_data, maxlen=125, padding='pre', truncating='post', value=len(word2ix) - 1)

# 保存成二进制文件
np.savez_compressed('./data/Poetry_data_word2ix_ix2word', data=pad_data, word2ix=word2ix, ix2word=ix2word)
# Out:
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.0.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.1000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.10000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.100000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.101000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.102000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.103000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.104000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.105000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.106000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.107000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.108000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.109000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.11000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.110000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.111000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.112000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.113000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.114000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.115000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.116000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.117000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.118000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.119000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.12000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.120000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.121000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.122000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.123000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.124000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.125000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.126000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.127000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.128000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.129000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.13000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.130000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.131000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.132000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.133000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.134000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.135000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.136000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.137000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.138000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.139000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.14000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.140000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.141000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.142000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.143000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.144000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.145000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.146000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.147000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.148000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.149000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.15000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.150000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.151000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.152000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.153000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.154000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.155000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.156000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.157000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.158000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.159000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.16000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.160000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.161000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.162000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.163000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.164000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.165000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.166000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.167000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.168000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.169000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.17000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.170000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.171000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.172000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.173000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.174000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.175000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.176000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.177000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.178000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.179000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.18000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.180000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.181000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.182000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.183000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.184000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.185000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.186000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.187000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.188000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.189000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.19000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.190000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.191000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.192000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.193000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.194000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.195000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.196000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.197000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.198000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.199000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.2000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.20000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.200000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.201000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.202000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.203000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.204000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.205000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.206000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.207000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.208000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.209000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.21000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.210000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.211000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.212000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.213000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.214000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.215000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.216000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.217000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.218000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.219000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.22000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.220000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.221000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.222000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.223000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.224000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.225000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.226000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.227000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.228000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.229000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.23000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.230000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.231000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.232000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.233000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.234000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.235000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.236000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.237000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.238000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.239000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.24000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.240000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.241000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.242000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.243000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.244000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.245000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.246000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.247000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.248000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.249000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.25000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.250000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.251000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.252000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.253000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.254000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.26000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.27000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.28000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.29000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.3000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.30000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.31000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.32000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.33000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.34000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.35000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.36000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.37000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.38000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.39000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.4000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.40000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.41000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.42000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.43000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.44000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.45000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.46000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.47000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.48000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.49000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.5000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.50000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.51000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.52000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.53000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.54000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.55000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.56000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.57000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.58000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.59000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.6000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.60000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.61000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.62000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.63000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.64000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.65000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.66000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.67000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.68000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.69000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.7000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.70000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.71000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.72000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.73000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.74000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.75000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.76000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.77000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.78000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.79000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.8000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.80000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.81000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.82000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.83000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.84000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.85000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.86000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.87000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.88000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.89000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.9000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.90000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.91000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.92000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.93000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.94000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.95000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.96000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.97000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.98000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.song.99000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.tang.0.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.tang.1000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.tang.10000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.tang.11000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.tang.12000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.tang.13000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.tang.14000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.tang.15000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.tang.16000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.tang.17000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.tang.18000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.tang.19000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.tang.2000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.tang.20000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.tang.21000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.tang.22000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.tang.23000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.tang.24000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.tang.25000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.tang.26000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.tang.27000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.tang.28000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.tang.29000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.tang.3000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.tang.30000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.tang.31000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.tang.32000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.tang.33000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.tang.34000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.tang.35000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.tang.36000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.tang.37000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.tang.38000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.tang.39000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.tang.4000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.tang.40000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.tang.41000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.tang.42000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.tang.43000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.tang.44000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.tang.45000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.tang.46000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.tang.47000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.tang.48000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.tang.49000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.tang.5000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.tang.50000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.tang.51000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.tang.52000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.tang.53000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.tang.54000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.tang.55000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.tang.56000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.tang.57000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.tang.6000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.tang.7000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.tang.8000.json
# Processing C:/Users/nkxuj/Documents/Work/上课/Python-AI 2021/古诗生成作业/数据预处理/json/poet.tang.9000.json
